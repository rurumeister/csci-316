# %% [markdown]
# ## **GROUP ASSIGNMENT 1**

# %% [markdown]
# ### Importing data and reading

# %%
#imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read the data file
data = pd.read_csv('data.csv')

# see the first 20 columns
data.head(5)
# Out:
# /var/folders/bt/vkg37vm51db7424mjftzw2700000gn/T/ipykernel_64014/2979515366.py:2: DtypeWarning: Columns (17,45,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data.csv')
#        zid  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# ...

# %% [markdown]
# ## SETTINGS TO SEE ALL THE DATA IN WHATEVER WAY YOU WANT

# %%
# Be able to see all the columns
pd.set_option('display.max_columns', None)

# %%
# Reset setting
pd.reset_option('display.max_columns')

# %% [markdown]
# ## SEE THINGS NOW

# %% [markdown]
# ## (a) “discover and visualise the data”
#
# ### for this, we will have to preprocess some of the data first in order to visualize (encoding)

# %%
data['default_ind'].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data['default_ind'].corr()
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'

# %%
# get info on data and show all columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   zid                          855969 non-null  int64
#  1   member_id                    855969 non-null  int64
#  2   loan_amnt                    855969 non-null  int64
#  3   funded_amnt                  855969 non-null  int64
#  4   funded_amnt_inv              855969 non-null  float64
#  5   term                         855969 non-null  object
#  6   int_rate                     855969 non-null  float64
#  7   installment                  855969 non-null  float64
#  8   grade                        855969 non-null  object
#  9   sub_grade                    855969 non-null  object
#  10  emp_title                    806526 non-null  object
#  11  emp_length                   812908 non-null  object
# ...

# %% [markdown]
# ### Show columns with missing values

# %%
# Show all columns that have missing values
data.isnull().sum()
# Out:
# zid                      0
# member_id                0
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                      ...
# total_rev_hi_lim     67313
# inq_fi              842681
# total_cu_tl         842681
# inq_last_12m        842681
# default_ind              0
# Length: 73, dtype: int64

# %% [markdown]
# ### The following columns, we can ask Liu Kaiping (tutor) if can just put value as 0 for these columns

# %%
# Check type of this data column thing
# see the type of data['earliest_cr_line']
type(data['earliest_cr_line'].iloc[0])
# Out:
# str

# %%
# see all the values of 'emp_title'
data['emp_title'].value_counts()
# Out:
# emp_title
# Teacher                            12965
# Manager                            10821
# Registered Nurse                    5341
# RN                                  5182
# Owner                               5157
#                                    ...
# Pace                                   1
# D&H Enterprises                        1
# synergy llc                            1
# Nexion Health Inc                      1
# Manager Hotel Operations Oasis         1
# Name: count, Length: 290910, dtype: int64

# %%
# see all the values of 'open_acc_6m'
data['open_acc_6m'].value_counts(dropna=False)
# Out:
# open_acc_6m
# NaN     842681
# 0.0       5228
# 1.0       4285
# 2.0       2288
# 3.0        919
# 4.0        354
# 5.0        125
# 6.0         53
# 7.0         20
# 8.0          9
# 9.0          5
# 12.0         2
# Name: count, dtype: int64

# %%
# see all the values of 'verification_status_joint'
data['verification_status_joint'].value_counts()

# Potential to put as 'Not Verified' for null values???
# Out:
# verification_status_joint
# Not Verified       252
# Verified           139
# Source Verified     51
# Name: count, dtype: int64

# %%
# see all the values of 'open_acc_6m'
data['open_acc_6m'].value_counts()
    
# data['open_acc_12m'].value_counts()
# data['open_acc_24m'].value_counts()
# data['open_acc_12m'].value_counts()

# Confirm if null values can be changed to zero for these columns

# Will changing the null values to 0 mean that the person has open accounts? (6/12/24 months)
# Out:
# open_acc_6m
# 0.0     5228
# 1.0     4285
# 2.0     2288
# 3.0      919
# 4.0      354
# 5.0      125
# 6.0       53
# 7.0       20
# 8.0        9
# 9.0        5
# 12.0       2
# Name: count, dtype: int64

# %%
# see all the values of 'total_bal_il'
data['total_bal_il'].value_counts()
# Out:
# total_bal_il
# 0.0         1354
# 11536.0        4
# 23454.0        3
# 44140.0        3
# 12582.0        3
#             ...
# 10538.0        1
# 1091.0         1
# 15754.0        1
# 124038.0       1
# 39693.0        1
# Name: count, Length: 11099, dtype: int64

# %%
# look for rows where value of 'total_rev_hi_lim' is not null
data[data['total_rev_hi_lim'].notnull()]
# Out:
#              zid  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 39694   10149342   12000897      27050        27050          27050.0
# 39695   10159584   12011200       9750         9750           9750.0
# 39696   10159498    1319523      12000        12000          12000.0
# 39697   10139658   11991209      12000        12000          12000.0
# 39698   10159548   12011167      15000        15000          15000.0
# ...          ...        ...        ...          ...              ...
# 855964  36371250   39102635      10000        10000          10000.0
# 855965  36441262   39152692      24000        24000          24000.0
# 855966  36271333   38982739      13000        13000          13000.0
# 855967  36490806   39222577      12000        12000          12000.0
# 855968  36271262   38982659      20000        20000          20000.0
#
#               term  int_rate  installment grade sub_grade  \
# 39694    36 months     10.99       885.46     B        B2
# ...

# %% [markdown]
# ## STUFF WE ARE PLAYING AROUND WITH

# %%
# see all the values of 'acc_now_delinq'
data['acc_now_delinq'].value_counts()
# Out:
# acc_now_delinq
# 0     852039
# 1       3693
# 2        198
# 3         28
# 4          6
# 5          3
# 6          1
# 14         1
# Name: count, dtype: int64

# %%
# see all the values of 'emp_length'
data['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    282090
# 2 years       75986
# < 1 year      67597
# 3 years       67392
# 1 year        54855
# 5 years       53812
# 4 years       50643
# 7 years       43204
# 8 years       42421
# 6 years       41446
# 9 years       33462
# Name: count, dtype: int64

# %%
# find all the rows where 'acc_now_delinq' is = 14
data[data['acc_now_delinq'] == 14]
# Out:
#              zid  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 794721  42453230   45419943       7075         7075           7075.0
#
#               term  int_rate  installment grade sub_grade  ... il_util  \
# 794721   36 months     18.25       256.67     E        E1  ...     NaN
#
#        open_rv_12m open_rv_24m  max_bal_bc all_util total_rev_hi_lim inq_fi  \
# 794721         NaN         NaN         NaN      NaN           7600.0    NaN
#
#        total_cu_tl inq_last_12m default_ind
# 794721         NaN          NaN           0
#
# [1 rows x 73 columns]

# %% [markdown]
# ### VISUALISE DATA

# %%
# use seaborn to see the distribution of target column, 'default_ind'
sns.countplot(x='default_ind', data=data)
# Out:
# <Axes: xlabel='default_ind', ylabel='count'>

# %%
# use seaborn to create a countplot of 'emp_length'
sns.countplot(x='emp_length', data=data)
# Out:
# <Axes: xlabel='emp_length', ylabel='count'>

# %% [markdown]
# ### We will want to use correlation heatmaps to determine columns most correlated to Y

# %%
# Get correlation of all the columns
corr_crit_temp : pd.Series = data.corr()['default_ind']
highest_corr_attr : str = ''
highest_corr_val : float = 0.0

corr_crit_temp = data.corr()[['default_ind']].sort_values(by='default_ind', ascending=False)

# Get the highest correlation value
highest_corr_val = corr_crit_temp['default_ind'][1]

# Get the highest correlation attribute
highest_corr_attr = corr_crit_temp.index[1]

plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 2
#       1 # Get correlation of all the columns
# ----> 2 corr_crit_temp : pd.Series = data.corr()['default_ind']
#       3 highest_corr_attr : str = ''
#       4 highest_corr_val : float = 0.0
#
# File ~/miniconda3/envs/tryEnv/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/miniconda3/envs/tryEnv/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...

# %% [markdown]
# ### PLAYING AROUND: SPLITTIG USING train_test_split

# %%
# split the data using train_test_split
from sklearn.model_selection import train_test_split

# drop the target column
X = data.drop('default_ind', axis=1)

# set the target column
y = data['default_ind']

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101, stratify=y)

# %%
# See the shape of the train and test data
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# see head of train data
# print(X_train.head())
# Out:
# (684775, 72)
# (171194, 72)
# (684775,)
# (171194,)
